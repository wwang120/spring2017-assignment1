# %% [markdown]
# # Downloading Gaia data
#
# This notebook is a simple example of downloading Gaia data, loading it in, and doing simple plots of it.

# %%
# !/usr/bin/curl -OJ https://girder.hub.yt/api/v1/file/57fcf27bb8805f000164ab40/download
# Out:
# 系统找不到指定的路径。

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = {}
with h5py.File("gaia_validp.h5") as f:
    for k in f:
        data[k] = f[k][:]

# %%
print(data.keys())
# Out:
# dict_keys(['pmdec', 'phot_g_mean_mag', 'parallax', 'ra', 'dec', 'pmra'])

# %%
plt.plot(data['phot_g_mean_mag'])

# %%
data['dec'].max()
# Out:
# 89.832347190748962

# %%
data['dec'].min()
"""
this way is much faster than use min() function
"""
# Out:
# -89.889704453339718

# %%
data['dec']+data['ra']
# Out:
# array([  45.269722  ,   45.36507446,   45.33498028, ...,  314.93970227,
#         314.51253456,  314.73942978])

# %%
plt.hexbin(x = data['dec'],y = data['ra'],cmap ='magma')
